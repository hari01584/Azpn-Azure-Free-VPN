# %% [markdown]
# ### Azpn : Azure VPN Free (For Students Plan)
# _Premise: Azure student plan gives students a good 100 dollars starter credits yearly, we can use this quota to provide ourself with very cheap but useful VPN Server_
#
# ### Setup
# Download required depedency! azure-cli

# %%
pip install azure-cli
# Out:
# Requirement already satisfied: azure-cli in c:\programdata\anaconda3\lib\site-packages (2.33.1)
# Requirement already satisfied: azure-mgmt-privatedns~=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-signalr~=1.0.0b2 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-dns~=8.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (8.0.0)
# Requirement already satisfied: azure-mgmt-marketplaceordering==1.1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.1.0)
# Requirement already satisfied: azure-mgmt-synapse~=2.1.0b2 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (2.1.0b4)
# Requirement already satisfied: azure-cosmos>=3.0.2,~=3.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (3.2.0)
# Requirement already satisfied: sshtunnel~=0.1.4 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.1.5)
# Requirement already satisfied: azure-mgmt-containerservice~=16.4.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (16.4.0)
# Requirement already satisfied: azure-mgmt-reservations==0.6.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.6.0)
# Requirement already satisfied: azure-synapse-artifacts~=0.10.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.10.0)
# Requirement already satisfied: azure-mgmt-iotcentral~=9.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied: azure-mgmt-policyinsights~=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-redhatopenshift==1.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-hdinsight~=9.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied: azure-mgmt-storage~=19.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (19.0.0)
# Requirement already satisfied: chardet~=3.0.4 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (3.0.4)
# Requirement already satisfied: azure-mgmt-imagebuilder~=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-compute~=23.1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (23.1.0)
# Requirement already satisfied: semver==2.13.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (2.13.0)
# Requirement already satisfied: azure-keyvault-keys==4.5.0b4 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (4.5.0b4)
# Requirement already satisfied: azure-mgmt-loganalytics~=12.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (12.0.0)
# Requirement already satisfied: azure-mgmt-cognitiveservices~=13.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (13.0.0)
# Requirement already satisfied: azure-mgmt-datamigration~=10.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (10.0.0)
# Requirement already satisfied: azure-mgmt-advisor==9.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied: azure-graphrbac~=0.60.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.60.0)
# Requirement already satisfied: azure-mgmt-deploymentmanager~=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.2.0)
# Requirement already satisfied: azure-mgmt-iothubprovisioningservices~=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-servicebus~=6.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (6.0.0)
# Requirement already satisfied: azure-mgmt-managedservices~=1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-maps~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied: azure-mgmt-resource==20.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (20.0.0)
# Requirement already satisfied: azure-mgmt-sql~=3.0.1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (3.0.1)
# Requirement already satisfied: azure-mgmt-authorization~=0.61.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.61.0)
# Requirement already satisfied: azure-mgmt-servicefabric~=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-botservice~=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.3.0)
# Requirement already satisfied: azure-mgmt-security~=2.0.0b1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (2.0.0b1)
# Requirement already satisfied: scp~=0.13.2 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.13.6)
# Requirement already satisfied: azure-mgmt-keyvault==9.3.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (9.3.0)
# Requirement already satisfied: azure-storage-common~=1.4 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.4.2)
# Requirement already satisfied: antlr4-python3-runtime~=4.7.2 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (4.7.2)
# Requirement already satisfied: azure-mgmt-redis~=13.1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (13.1.0)
# Requirement already satisfied: azure-mgmt-netapp~=6.0.1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (6.0.1)
# Requirement already satisfied: azure-mgmt-recoveryservices~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied: azure-mgmt-consumption~=2.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied: fabric~=2.4 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (2.6.0)
# Requirement already satisfied: packaging<22.0,>=20.9 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (21.3)
# Requirement already satisfied: azure-mgmt-network~=19.3.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (19.3.0)
# Requirement already satisfied: azure-batch~=11.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (11.0.0)
# Requirement already satisfied: azure-synapse-managedprivateendpoints~=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.3.0)
# Requirement already satisfied: azure-mgmt-apimanagement~=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.2.0)
# Requirement already satisfied: azure-mgmt-devtestlabs~=4.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (4.0.0)
# Requirement already satisfied: azure-mgmt-managementgroups~=0.1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.2.0)
# Requirement already satisfied: xmltodict~=0.12 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.12.0)
# Requirement already satisfied: azure-mgmt-rdbms~=10.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (10.0.0)
# Requirement already satisfied: azure-multiapi-storage~=0.7.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.7.0)
# Requirement already satisfied: azure-mgmt-web~=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (4.0.0)
# Requirement already satisfied: PyNaCl~=1.4.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.4.0)
# Requirement already satisfied: azure-mgmt-relay~=0.1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.1.0)
# Requirement already satisfied: colorama~=0.4.4 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.4.4)
# Requirement already satisfied: azure-mgmt-batch~=16.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (16.0.0)
# Requirement already satisfied: azure-synapse-accesscontrol~=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.5.0)
# Requirement already satisfied: azure-loganalytics~=0.1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.1.1)
# Requirement already satisfied: azure-mgmt-eventgrid==9.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (9.0.0)
# Requirement already satisfied: azure-cli-core==2.33.1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (2.33.1)
# Requirement already satisfied: azure-mgmt-extendedlocation~=1.0.0b2 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: urllib3[secure] in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.26.8)
# Requirement already satisfied: javaproperties~=0.5.1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.5.2)
# Requirement already satisfied: azure-mgmt-containerinstance~=9.1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (9.1.0)
# Requirement already satisfied: azure-mgmt-appconfiguration~=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (2.0.0)
# Requirement already satisfied: azure-mgmt-iothub==2.1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (2.1.0)
# Requirement already satisfied: PyGithub~=1.38 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.55)
# Requirement already satisfied: azure-mgmt-recoveryservicesbackup~=4.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (4.0.0)
# Requirement already satisfied: azure-mgmt-servicelinker==1.0.0b1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0b1)
# Requirement already satisfied: azure-synapse-spark~=0.2.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.2.0)
# Requirement already satisfied: azure-mgmt-servicefabricmanagedclusters~=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-cdn==11.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (11.0.0)
# Requirement already satisfied: azure-mgmt-sqlvirtualmachine~=1.0.0b1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0b1)
# Requirement already satisfied: azure-keyvault~=1.1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.1.0)
# Requirement already satisfied: azure-mgmt-cosmosdb~=7.0.0b2 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (7.0.0b3)
# Requirement already satisfied: azure-mgmt-monitor~=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (3.0.0)
# Requirement already satisfied: azure-keyvault-administration==4.0.0b3 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (4.0.0b3)
# Requirement already satisfied: azure-mgmt-msi~=0.2 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.2.0)
# Requirement already satisfied: azure-mgmt-datalake-store~=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.5.0)
# Requirement already satisfied: azure-datalake-store~=0.0.49 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.0.52)
# Requirement already satisfied: azure-appconfiguration~=1.1.1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.1.1)
# Requirement already satisfied: jsondiff~=1.3.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.3.1)
# Requirement already satisfied: distro in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.7.0)
# Requirement already satisfied: azure-mgmt-kusto~=0.3.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.3.0)
# Requirement already satisfied: six>=1.10.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.15.0)
# Requirement already satisfied: azure-mgmt-batchai~=7.0.0b1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (7.0.0b1)
# Requirement already satisfied: azure-mgmt-containerregistry==8.2.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (8.2.0)
# Requirement already satisfied: azure-mgmt-billing==6.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (6.0.0)
# Requirement already satisfied: azure-mgmt-databoxedge~=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-eventhub~=9.1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (9.1.0)
# Requirement already satisfied: azure-identity in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.7.1)
# Requirement already satisfied: azure-mgmt-media~=7.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (7.0.0)
# Requirement already satisfied: azure-mgmt-search~=8.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (8.0.0)
# Requirement already satisfied: azure-mgmt-datalake-analytics~=0.2.1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.2.1)
# Requirement already satisfied: azure-mgmt-trafficmanager~=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: azure-mgmt-applicationinsights~=1.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (1.0.0)
# Requirement already satisfied: websocket-client~=0.56.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli) (0.56.0)
# Requirement already satisfied: azure-mgmt-core<2.0.0,>=1.2.0 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-privatedns~=1.0.0->azure-cli) (1.3.0)
# Requirement already satisfied: msrest>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-privatedns~=1.0.0->azure-cli) (0.6.21)
# Requirement already satisfied: azure-common~=1.1 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-privatedns~=1.0.0->azure-cli) (1.1.28)
# Requirement already satisfied: requests>=2.10.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cosmos>=3.0.2,~=3.0->azure-cli) (2.27.1)
# Requirement already satisfied: paramiko>=1.15.2 in c:\programdata\anaconda3\lib\site-packages (from sshtunnel~=0.1.4->azure-cli) (2.7.2)
# Requirement already satisfied: msrestazure<2.0.0,>=0.4.32 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-reservations==0.6.0->azure-cli) (0.6.4)
# Requirement already satisfied: azure-core<2.0.0,>=1.20.0 in c:\programdata\anaconda3\lib\site-packages (from azure-synapse-artifacts~=0.10.0->azure-cli) (1.22.1)
# Requirement already satisfied: cryptography>=2.1.4 in c:\programdata\anaconda3\lib\site-packages (from azure-keyvault-keys==4.5.0b4->azure-cli) (36.0.1)
# Requirement already satisfied: python-dateutil in c:\programdata\anaconda3\lib\site-packages (from azure-storage-common~=1.4->azure-cli) (2.8.1)
# Requirement already satisfied: azure-mgmt-nspkg>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-consumption~=2.0->azure-cli) (3.0.2)
# Requirement already satisfied: pathlib2 in c:\programdata\anaconda3\lib\site-packages (from fabric~=2.4->azure-cli) (2.3.5)
# Requirement already satisfied: invoke<2.0,>=1.3 in c:\programdata\anaconda3\lib\site-packages (from fabric~=2.4->azure-cli) (1.6.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\programdata\anaconda3\lib\site-packages (from packaging<22.0,>=20.9->azure-cli) (2.4.7)
# Requirement already satisfied: cffi>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from PyNaCl~=1.4.0->azure-cli) (1.14.3)
# Requirement already satisfied: argcomplete~=1.8 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core==2.33.1->azure-cli) (1.12.3)
# Requirement already satisfied: knack~=0.9.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core==2.33.1->azure-cli) (0.9.0)
# Requirement already satisfied: msal-extensions<0.4,>=0.3.1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core==2.33.1->azure-cli) (0.3.1)
# Requirement already satisfied: msal<2.0.0,>=1.16.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core==2.33.1->azure-cli) (1.17.0)
# Requirement already satisfied: pkginfo>=1.5.0.1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core==2.33.1->azure-cli) (1.8.2)
# Requirement already satisfied: pyopenssl>=17.1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core==2.33.1->azure-cli) (19.1.0)
# Requirement already satisfied: azure-cli-telemetry==1.0.6.* in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core==2.33.1->azure-cli) (1.0.6)
# Requirement already satisfied: jmespath in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core==2.33.1->azure-cli) (0.10.0)
# Requirement already satisfied: PyJWT>=2.1.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core==2.33.1->azure-cli) (2.3.0)
# Requirement already satisfied: psutil~=5.9 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core==2.33.1->azure-cli) (5.9.0)
# Requirement already satisfied: humanfriendly~=10.0 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-core==2.33.1->azure-cli) (10.0)
# Requirement already satisfied: certifi; extra == "secure" in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure]->azure-cli) (2020.6.20)
# Requirement already satisfied: idna>=2.0.0; extra == "secure" in c:\programdata\anaconda3\lib\site-packages (from urllib3[secure]->azure-cli) (2.10)
# Requirement already satisfied: deprecated in c:\programdata\anaconda3\lib\site-packages (from PyGithub~=1.38->azure-cli) (1.2.13)
# Requirement already satisfied: azure-nspkg>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-keyvault~=1.1.0->azure-cli) (3.0.2)
# Requirement already satisfied: azure-mgmt-datalake-nspkg>=2.0.0 in c:\programdata\anaconda3\lib\site-packages (from azure-mgmt-datalake-store~=0.5.0->azure-cli) (3.0.1)
# Requirement already satisfied: adal>=0.4.2 in c:\programdata\anaconda3\lib\site-packages (from azure-datalake-store~=0.0.49->azure-cli) (1.2.7)
# Requirement already satisfied: isodate>=0.6.0 in c:\programdata\anaconda3\lib\site-packages (from msrest>=0.5.0->azure-mgmt-privatedns~=1.0.0->azure-cli) (0.6.1)
# Requirement already satisfied: requests-oauthlib>=0.5.0 in c:\programdata\anaconda3\lib\site-packages (from msrest>=0.5.0->azure-mgmt-privatedns~=1.0.0->azure-cli) (1.3.0)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in c:\programdata\anaconda3\lib\site-packages (from requests>=2.10.0->azure-cosmos>=3.0.2,~=3.0->azure-cli) (2.0.11)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\programdata\anaconda3\lib\site-packages (from paramiko>=1.15.2->sshtunnel~=0.1.4->azure-cli) (3.2.0)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.4.1->PyNaCl~=1.4.0->azure-cli) (2.20)
# Requirement already satisfied: pyyaml in c:\programdata\anaconda3\lib\site-packages (from knack~=0.9.0->azure-cli-core==2.33.1->azure-cli) (5.3.1)
# Requirement already satisfied: tabulate in c:\users\hari0\appdata\roaming\python\python38\site-packages (from knack~=0.9.0->azure-cli-core==2.33.1->azure-cli) (0.8.9)
# Requirement already satisfied: pygments in c:\programdata\anaconda3\lib\site-packages (from knack~=0.9.0->azure-cli-core==2.33.1->azure-cli) (2.7.2)
# Requirement already satisfied: portalocker<3,>=1.6; python_version >= "3.5" and platform_system == "Windows" in c:\programdata\anaconda3\lib\site-packages (from msal-extensions<0.4,>=0.3.1->azure-cli-core==2.33.1->azure-cli) (1.7.1)
# Requirement already satisfied: applicationinsights<0.12,>=0.11.1 in c:\programdata\anaconda3\lib\site-packages (from azure-cli-telemetry==1.0.6.*->azure-cli-core==2.33.1->azure-cli) (0.11.10)
# Requirement already satisfied: pyreadline3; sys_platform == "win32" and python_version >= "3.8" in c:\programdata\anaconda3\lib\site-packages (from humanfriendly~=10.0->azure-cli-core==2.33.1->azure-cli) (3.4.1)
# Requirement already satisfied: wrapt<2,>=1.10 in c:\programdata\anaconda3\lib\site-packages (from deprecated->PyGithub~=1.38->azure-cli) (1.12.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\programdata\anaconda3\lib\site-packages (from requests-oauthlib>=0.5.0->msrest>=0.5.0->azure-mgmt-privatedns~=1.0.0->azure-cli) (3.1.0)
# Requirement already satisfied: pywin32!=226; platform_system == "Windows" in c:\programdata\anaconda3\lib\site-packages (from portalocker<3,>=1.6; python_version >= "3.5" and platform_system == "Windows"->msal-extensions<0.4,>=0.3.1->azure-cli-core==2.33.1->azure-cli) (227)
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install paramiko
# Out:
# Requirement already satisfied: paramiko in c:\programdata\anaconda3\lib\site-packages (2.7.2)
# Requirement already satisfied: bcrypt>=3.1.3 in c:\programdata\anaconda3\lib\site-packages (from paramiko) (3.2.0)
# Requirement already satisfied: pynacl>=1.0.1 in c:\programdata\anaconda3\lib\site-packages (from paramiko) (1.4.0)
# Requirement already satisfied: cryptography>=2.5 in c:\programdata\anaconda3\lib\site-packages (from paramiko) (36.0.1)
# Requirement already satisfied: six>=1.4.1 in c:\programdata\anaconda3\lib\site-packages (from bcrypt>=3.1.3->paramiko) (1.15.0)
# Requirement already satisfied: cffi>=1.1 in c:\programdata\anaconda3\lib\site-packages (from bcrypt>=3.1.3->paramiko) (1.14.3)
# Requirement already satisfied: pycparser in c:\programdata\anaconda3\lib\site-packages (from cffi>=1.1->bcrypt>=3.1.3->paramiko) (2.20)
# Note: you may need to restart the kernel to use updated packages.
